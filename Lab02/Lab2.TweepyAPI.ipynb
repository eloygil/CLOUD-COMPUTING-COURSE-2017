# %%
import tweepy
from tweepy import OAuthHandler

consumer_key = ''
consumer_secret = ''
access_token = ''
access_secret = ''

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

user = api.me()

print('Name: ' + user.name)
print('Location: ' + user.location)
print('Friends: ' + str(user.followers_count))
print('Created: ' + str(user.created_at))
print('Description: ' + str(user.description))
# Out:
# Name: Eloy 'eloyweb' Gil
# Location: «To be or not to be...» in BCN
# Friends: 558
# Created: 2009-01-25 15:12:47
# Description: 199x. Designed in Navarra, assembled in Barcelona. Professional photographer, computer sciences by punishment. Proud shareholder of Twitter & Facebook.

# %%
# Getting the text of a tweet from our Timeline
for status in tweepy.Cursor(api.home_timeline).items(1):
    print(status.text)
# Out:
# When you're The One and you don't even know it @LDLC_ALEX
#
# #ESLProLeague https://t.co/sVZrkl5R8B
# El programa de hoy está disponible en Youtube.
#
# https://t.co/6sgkJNSfuS
# RT @Vlesk: https://t.co/5ZgkX2zRjL
# You just be your beautiful self @Sadokist! 🙆🏻‍♂️ #ESLProLeague https://t.co/SEE4AgMmmZ
# ESTAS SKINS.
# SON
# LA
# VIDA https://t.co/d1OQhc60y2

# %%
# Getting that tweet in JSON format
import json

for status in tweepy.Cursor(api.home_timeline).items(1):
    print(json.dumps(status._json, indent=2))
# Out:
# {
#   "contributors": null,
#   "truncated": false,
#   "text": "When you're The One and you don't even know it @LDLC_ALEX\n\n#ESLProLeague https://t.co/sVZrkl5R8B",
#   "is_quote_status": false,
#   "in_reply_to_status_id": null,
#   "id": 839226872248610817,
#   "favorite_count": 49,
#   "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#     "symbols": [],
#     "user_mentions": [
#       {
#         "id": 2339429359,
#         "indices": [
#           47,
#           57
#         ],
#         "id_str": "2339429359",
#         "screen_name": "LDLC_ALEX",
#         "name": "Alex"
#       }
#     ],
#     "hashtags": [
#       {
#         "indices": [
#           59,
#           72
#         ],
#         "text": "ESLProLeague"
#       }
#     ],
#     "urls": [],
#     "media": [
#       {
#         "expanded_url": "https://twitter.com/ESLCS/status/839226872248610817/photo/1",
#         "display_url": "pic.twitter.com/sVZrkl5R8B",
#         "url": "https://t.co/sVZrkl5R8B",
#         "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/C6WH-KjXMAA_8VJ.jpg",
#         "id_str": "839226407628779520",
#         "sizes": {
#           "small": {
#             "h": 191,
#             "resize": "fit",
#             "w": 340
#           },
#           "large": {
#             "h": 576,
#             "resize": "fit",
#             "w": 1024
#           },
#           "medium": {
#             "h": 338,
#             "resize": "fit",
#             "w": 600
#           },
#           "thumb": {
#             "h": 150,
#             "resize": "crop",
#             "w": 150
#           }
#         },
#         "indices": [
#           73,
#           96
#         ],
#         "type": "photo",
#         "id": 839226407628779520,
#         "media_url": "http://pbs.twimg.com/tweet_video_thumb/C6WH-KjXMAA_8VJ.jpg"
#       }
#     ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 8,
#   "id_str": "839226872248610817",
#   "favorited": false,
#   "user": {
#     "follow_request_sent": false,
#     "has_extended_profile": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 34002876,
#     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/443184636466716672/5Fhg88BU.jpeg",
#     "verified": true,
#     "translator_type": "regular",
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/520216646502191106/7lTQCzzd_normal.jpeg",
#     "profile_sidebar_fill_color": "F3F3F3",
#     "entities": {
#       "url": {
#         "urls": [
#           {
#             "url": "https://t.co/igodGGzOjb",
#             "indices": [
#               0,
#               23
#             ],
#             "expanded_url": "http://play.eslgaming.com/counterstrike/csgo/",
#             "display_url": "play.eslgaming.com/counterstrike/\u2026"
#           }
#         ]
#       },
#       "description": {
#         "urls": []
#       }
#     },
#     "followers_count": 763914,
#     "profile_sidebar_border_color": "FFFFFF",
#     "id_str": "34002876",
#     "profile_background_color": "EBEBEB",
#     "listed_count": 719,
#     "is_translation_enabled": false,
#     "utc_offset": 3600,
#     "statuses_count": 13059,
#     "description": "Home of all CS titles on @ESL - the world's largest esports company! Follow us to be the first to know about #ESLOne, #ESLProLeague, #Go4CSGO & more!",
#     "friends_count": 326,
#     "location": "Worldwide",
#     "profile_link_color": "990000",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/520216646502191106/7lTQCzzd_normal.jpeg",
#     "following": true,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/34002876/1470668686",
#     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/443184636466716672/5Fhg88BU.jpeg",
#     "screen_name": "ESLCS",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 1122,
#     "name": "ESL Counter-Strike",
#     "notifications": false,
#     "url": "https://t.co/igodGGzOjb",
#     "created_at": "Tue Apr 21 19:06:35 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Bern",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "possibly_sensitive_appealable": false,
#   "lang": "en",
#   "created_at": "Tue Mar 07 21:30:53 +0000 2017",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "extended_entities": {
#     "media": [
#       {
#         "expanded_url": "https://twitter.com/ESLCS/status/839226872248610817/photo/1",
#         "display_url": "pic.twitter.com/sVZrkl5R8B",
#         "url": "https://t.co/sVZrkl5R8B",
#         "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/C6WH-KjXMAA_8VJ.jpg",
#         "video_info": {
#           "aspect_ratio": [
#             16,
#             9
#           ],
#           "variants": [
#             {
#               "url": "https://video.twimg.com/tweet_video/C6WH-KjXMAA_8VJ.mp4",
#               "bitrate": 0,
#               "content_type": "video/mp4"
#             }
#           ]
#         },
#         "id_str": "839226407628779520",
#         "sizes": {
#           "small": {
#             "h": 191,
#             "resize": "fit",
#             "w": 340
#           },
#           "large": {
#             "h": 576,
#             "resize": "fit",
#             "w": 1024
#           },
#           "medium": {
#             "h": 338,
#             "resize": "fit",
#             "w": 600
#           },
#           "thumb": {
#             "h": 150,
#             "resize": "crop",
#             "w": 150
#           }
#         },
#         "indices": [
#           73,
#           96
#         ],
#         "type": "animated_gif",
#         "id": 839226407628779520,
#         "media_url": "http://pbs.twimg.com/tweet_video_thumb/C6WH-KjXMAA_8VJ.jpg"
#       }
#     ]
#   }
# }

# %%
# Some of my own friends in JSON format
for friend in tweepy.Cursor(api.friends).items(10):
    print(json.dumps(friend._json, indent=2))
# Out:
# {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": false,
#   "live_following": false,
#   "default_profile_image": false,
#   "id": 276958246,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/227975004/riot.jpg",
#   "translator_type": "none",
#   "verified": false,
#   "blocked_by": false,
#   "profile_text_color": "333333",
#   "muting": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/3603706227/cb269ce2c5bb793eee8944d2c449b1d6_normal.jpeg",
#   "profile_sidebar_fill_color": "EFEFEF",
#   "entities": {
#     "url": {
#       "urls": [
#         {
#           "url": "http://t.co/FEmc1n0a0W",
#           "indices": [
#             0,
#             22
#           ],
#           "expanded_url": "http://www.riotgames.com/careers",
#           "display_url": "riotgames.com/careers"
#         }
#       ]
#     },
#     "description": {
#       "urls": []
#     }
#   },
#   "followers_count": 99770,
#   "profile_sidebar_border_color": "000000",
#   "id_str": "276958246",
#   "profile_background_color": "000000",
#   "listed_count": 204,
#   "status": {
#     "contributors": null,
#     "truncated": false,
#     "text": "Each intern has a unique story that brought them to Riot. Check out 'Daniel's Story' #gdc17 https://t.co/q6H0CCTCa4",
#     "is_quote_status": false,
#     "in_reply_to_status_id": null,
#     "id": 837804545740693504,
#     "favorite_count": 51,
#     "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "entities": {
#       "symbols": [],
#       "user_mentions": [],
#       "hashtags": [
#         {
#           "indices": [
#             85,
#             91
#           ],
#           "text": "gdc17"
#         }
#       ],
#       "urls": [
#         {
#           "url": "https://t.co/q6H0CCTCa4",
#           "indices": [
#             92,
#             115
#           ],
#           "expanded_url": "https://www.youtube.com/watch?v=tIOI4qBqRas",
#           "display_url": "youtube.com/watch?v=tIOI4q\u2026"
#         }
#       ]
#     },
#     "in_reply_to_screen_name": null,
#     "in_reply_to_user_id": null,
#     "retweet_count": 10,
#     "id_str": "837804545740693504",
#     "favorited": false,
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "possibly_sensitive": false,
#     "lang": "en",
#     "created_at": "Fri Mar 03 23:19:04 +0000 2017",
#     "in_reply_to_status_id_str": null,
#     "place": null
#   },
#   "is_translation_enabled": false,
#   "utc_offset": -28800,
#   "statuses_count": 341,
#   "description": "Rioters wanted: we\u2019re looking for humble, but ambitious, razor-sharp pros who take play seriously.",
#   "friends_count": 2,
#   "location": "Santa Monica, CA",
#   "profile_link_color": "009999",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/3603706227/cb269ce2c5bb793eee8944d2c449b1d6_normal.jpeg",
#   "following": true,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/276958246/1420471198",
#   "blocking": false,
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/227975004/riot.jpg",
#   "screen_name": "RiotCareers",
#   "lang": "en",
#   "profile_background_tile": false,
#   "favourites_count": 5,
#   "name": "Riot Games Careers",
#   "notifications": false,
#   "url": "http://t.co/FEmc1n0a0W",
#   "created_at": "Mon Apr 04 12:32:15 +0000 2011",
#   "contributors_enabled": false,
#   "time_zone": "Pacific Time (US & Canada)",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
# }
# {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "live_following": false,
#   "default_profile_image": false,
#   "id": 997418796,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "translator_type": "none",
#   "verified": false,
#   "blocked_by": false,
#   "profile_text_color": "333333",
#   "muting": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/594854244911579136/ETjcr8ZG_normal.jpg",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "description": {
#       "urls": []
#     }
#   },
#   "followers_count": 142,
#   "profile_sidebar_border_color": "C0DEED",
#   "id_str": "997418796",
#   "profile_background_color": "C0DEED",
#   "listed_count": 0,
#   "status": {
#     "contributors": null,
#     "truncated": false,
#     "text": "I picked FNC to win their match against UOL https://t.co/qXWBmoNI1w #EULCS #FNCWIN",
#     "is_quote_status": false,
#     "in_reply_to_status_id": null,
#     "id": 772321749178339328,
#     "favorite_count": 14,
#     "source": "<a href=\"http://mobile.twitter.com\" rel=\"nofollow\">Mobile Web</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "entities": {
#       "symbols": [],
#       "user_mentions": [],
#       "hashtags": [
#         {
#           "indices": [
#             68,
#             74
#           ],
#           "text": "EULCS"
#         },
#         {
#           "indices": [
#             75,
#             82
#           ],
#           "text": "FNCWIN"
#         }
#       ],
#       "urls": [
#         {
#           "url": "https://t.co/qXWBmoNI1w",
#           "indices": [
#             44,
#             67
#           ],
#           "expanded_url": "http://www.lolesports.com/en_US/eu-lcs/eu_2016_summer/matches/eu_2016_regionals/match-b",
#           "display_url": "lolesports.com/en_US/eu-lcs/e\u2026"
#         }
#       ]
#     },
#     "in_reply_to_screen_name": null,
#     "in_reply_to_user_id": null,
#     "retweet_count": 2,
#     "id_str": "772321749178339328",
#     "favorited": false,
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "possibly_sensitive": false,
#     "lang": "en",
#     "created_at": "Sun Sep 04 06:33:48 +0000 2016",
#     "in_reply_to_status_id_str": null,
#     "place": null
#   },
#   "is_translation_enabled": false,
#   "utc_offset": null,
#   "statuses_count": 15,
#   "description": "",
#   "friends_count": 16,
#   "location": "",
#   "profile_link_color": "1DA1F2",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/594854244911579136/ETjcr8ZG_normal.jpg",
#   "following": true,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/997418796/1416556556",
#   "blocking": false,
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "screen_name": "EmmaSofiaa",
#   "lang": "sv",
#   "profile_background_tile": false,
#   "favourites_count": 36,
#   "name": "EmmaSofiaLarsson",
#   "notifications": false,
#   "url": null,
#   "created_at": "Sat Dec 08 15:52:37 +0000 2012",
#   "contributors_enabled": false,
#   "time_zone": null,
#   "protected": false,
#   "default_profile": true,
#   "is_translator": false
# }
# {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "live_following": false,
#   "default_profile_image": false,
#   "id": 303739857,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/676430777/c956f6038ae7087357eea3cf67da5906.jpeg",
#   "translator_type": "none",
#   "verified": false,
#   "blocked_by": false,
#   "profile_text_color": "333333",
#   "muting": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000692705583/015be2057821ebe8382c21804a8504fc_normal.png",
#   "profile_sidebar_fill_color": "EFEFEF",
#   "entities": {
#     "url": {
#       "urls": [
#         {
#           "url": "http://t.co/sRoZ19YFdV",
#           "indices": [
#             0,
#             22
#           ],
#           "expanded_url": "http://www.bsc.es",
#           "display_url": "bsc.es"
#         }
#       ]
#     },
#     "description": {
#       "urls": []
#     }
#   },
#   "followers_count": 3487,
#   "profile_sidebar_border_color": "FFFFFF",
#   "id_str": "303739857",
#   "profile_background_color": "131516",
#   "listed_count": 267,
#   "status": {
#     "contributors": null,
#     "truncated": false,
#     "text": "RT @ewanbirney: Congratulations to @BSC_CNS for hiring bioinformatics legend @Alfons_Valencia all bioinformatics roads lead to Barcelona in\u2026",
#     "is_quote_status": true,
#     "in_reply_to_status_id": null,
#     "id": 839182865858441218,
#     "favorite_count": 0,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "quoted_status_id": 839015285344600064,
#     "retweeted": false,
#     "coordinates": null,
#     "entities": {
#       "symbols": [],
#       "user_mentions": [
#         {
#           "id": 183548902,
#           "indices": [
#             3,
#             14
#           ],
#           "id_str": "183548902",
#           "screen_name": "ewanbirney",
#           "name": "Ewan Birney"
#         },
#         {
#           "id": 303739857,
#           "indices": [
#             35,
#             43
#           ],
#           "id_str": "303739857",
#           "screen_name": "BSC_CNS",
#           "name": "BSC-CNS"
#         },
#         {
#           "id": 245682624,
#           "indices": [
#             77,
#             93
#           ],
#           "id_str": "245682624",
#           "screen_name": "Alfons_Valencia",
#           "name": "AlfonsoValencia"
#         }
#       ],
#       "hashtags": [],
#       "urls": []
#     },
#     "in_reply_to_screen_name": null,
#     "in_reply_to_user_id": null,
#     "retweet_count": 28,
#     "id_str": "839182865858441218",
#     "favorited": false,
#     "retweeted_status": {
#       "contributors": null,
#       "truncated": true,
#       "text": "Congratulations to @BSC_CNS for hiring bioinformatics legend @Alfons_Valencia all bioinformatics roads lead to Barc\u2026 https://t.co/O626XeVMcX",
#       "is_quote_status": true,
#       "in_reply_to_status_id": null,
#       "id": 839018662350716928,
#       "favorite_count": 39,
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "quoted_status_id": 839015285344600064,
#       "retweeted": false,
#       "coordinates": null,
#       "entities": {
#         "symbols": [],
#         "user_mentions": [
#           {
#             "id": 303739857,
#             "indices": [
#               19,
#               27
#             ],
#             "id_str": "303739857",
#             "screen_name": "BSC_CNS",
#             "name": "BSC-CNS"
#           },
#           {
#             "id": 245682624,
#             "indices": [
#               61,
#               77
#             ],
#             "id_str": "245682624",
#             "screen_name": "Alfons_Valencia",
#             "name": "AlfonsoValencia"
#           }
#         ],
#         "hashtags": [],
#         "urls": [
#           {
#             "url": "https://t.co/O626XeVMcX",
#             "indices": [
#               117,
#               140
#             ],
#             "expanded_url": "https://twitter.com/i/web/status/839018662350716928",
#             "display_url": "twitter.com/i/web/status/8\u2026"
#           }
#         ]
#       },
#       "in_reply_to_screen_name": null,
#       "in_reply_to_user_id": null,
#       "retweet_count": 28,
#       "id_str": "839018662350716928",
#       "favorited": false,
#       "geo": null,
#       "in_reply_to_user_id_str": null,
#       "possibly_sensitive": false,
#       "lang": "en",
#       "created_at": "Tue Mar 07 07:43:31 +0000 2017",
#       "quoted_status_id_str": "839015285344600064",
#       "in_reply_to_status_id_str": null,
#       "place": null
#     },
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "lang": "en",
#     "created_at": "Tue Mar 07 18:36:01 +0000 2017",
#     "quoted_status_id_str": "839015285344600064",
#     "in_reply_to_status_id_str": null,
#     "place": null
#   },
#   "is_translation_enabled": false,
#   "utc_offset": -10800,
#   "statuses_count": 5589,
#   "description": "BSC-CNS (Barcelona Supercomputing Center-Centro Nacional de Supercomputaci\u00f3n) is the National Supercomputing Facility in Spain.",
#   "friends_count": 1191,
#   "location": "Barcelona ",
#   "profile_link_color": "89C9FA",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/378800000692705583/015be2057821ebe8382c21804a8504fc_normal.png",
#   "following": true,
#   "geo_enabled": true,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/303739857/1443017028",
#   "blocking": false,
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/676430777/c956f6038ae7087357eea3cf67da5906.jpeg",
#   "screen_name": "BSC_CNS",
#   "lang": "es",
#   "profile_background_tile": false,
#   "favourites_count": 1995,
#   "name": "BSC-CNS",
#   "notifications": false,
#   "url": "http://t.co/sRoZ19YFdV",
#   "created_at": "Mon May 23 10:43:23 +0000 2011",
#   "contributors_enabled": false,
#   "time_zone": "Greenland",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
# }
# {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": false,
#   "live_following": false,
#   "default_profile_image": false,
#   "id": 20523846,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#   "translator_type": "none",
#   "verified": true,
#   "blocked_by": false,
#   "profile_text_color": "333333",
#   "muting": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/618843226997288960/42JK8BSu_normal.jpg",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "url": {
#       "urls": [
#         {
#           "url": "http://t.co/fLgZ6jJfM4",
#           "indices": [
#             0,
#             22
#           ],
#           "expanded_url": "http://riotgames.com",
#           "display_url": "riotgames.com"
#         }
#       ]
#     },
#     "description": {
#       "urls": []
#     }
#   },
#   "followers_count": 1373846,
#   "profile_sidebar_border_color": "FFFFFF",
#   "id_str": "20523846",
#   "profile_background_color": "131516",
#   "listed_count": 1848,
#   "status": {
#     "contributors": null,
#     "truncated": false,
#     "text": "Architecture to deployment, this is how Riot Messaging Service connects League players to one another. #RiotTechBlog https://t.co/0NITRd3Ayt",
#     "is_quote_status": false,
#     "in_reply_to_status_id": null,
#     "id": 836699502224498688,
#     "favorite_count": 212,
#     "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "entities": {
#       "symbols": [],
#       "user_mentions": [],
#       "hashtags": [
#         {
#           "indices": [
#             103,
#             116
#           ],
#           "text": "RiotTechBlog"
#         }
#       ],
#       "urls": [
#         {
#           "url": "https://t.co/0NITRd3Ayt",
#           "indices": [
#             117,
#             140
#           ],
#           "expanded_url": "http://riot.com/2lERQgZ",
#           "display_url": "riot.com/2lERQgZ"
#         }
#       ]
#     },
#     "in_reply_to_screen_name": null,
#     "in_reply_to_user_id": null,
#     "retweet_count": 42,
#     "id_str": "836699502224498688",
#     "favorited": false,
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "possibly_sensitive": false,
#     "lang": "en",
#     "created_at": "Tue Feb 28 22:08:01 +0000 2017",
#     "in_reply_to_status_id_str": null,
#     "place": null
#   },
#   "is_translation_enabled": false,
#   "utc_offset": -28800,
#   "statuses_count": 507,
#   "description": "Riot Games is the developer and publisher of League of Legends.",
#   "friends_count": 6,
#   "location": "Santa Monica, CA",
#   "profile_link_color": "080808",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/618843226997288960/42JK8BSu_normal.jpg",
#   "following": true,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/20523846/1398717616",
#   "blocking": false,
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#   "screen_name": "riotgames",
#   "lang": "en",
#   "profile_background_tile": true,
#   "favourites_count": 47,
#   "name": "Riot Games",
#   "notifications": false,
#   "url": "http://t.co/fLgZ6jJfM4",
#   "created_at": "Tue Feb 10 16:30:49 +0000 2009",
#   "contributors_enabled": false,
#   "time_zone": "Pacific Time (US & Canada)",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
# }
# {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "live_following": false,
#   "default_profile_image": false,
#   "id": 2909403579,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#   "translator_type": "none",
#   "verified": true,
#   "blocked_by": false,
#   "profile_text_color": "000000",
#   "muting": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/652220719770771456/aDxDVzIB_normal.png",
#   "profile_sidebar_fill_color": "000000",
#   "entities": {
#     "url": {
#       "urls": [
#         {
#           "url": "http://t.co/Si7szatA6y",
#           "indices": [
#             0,
#             22
#           ],
#           "expanded_url": "http://www.origen.gg",
#           "display_url": "origen.gg"
#         }
#       ]
#     },
#     "description": {
#       "urls": [
#         {
#           "url": "https://t.co/d0e1aUGdht",
#           "indices": [
#             0,
#             23
#           ],
#           "expanded_url": "http://www.Facebook.com/Origengg",
#           "display_url": "Facebook.com/Origengg"
#         },
#         {
#           "url": "https://t.co/JQQ4SygOb9",
#           "indices": [
#             24,
#             47
#           ],
#           "expanded_url": "http://www.Instagram.com/Origengg",
#           "display_url": "Instagram.com/Origengg"
#         },
#         {
#           "url": "https://t.co/eXXJXJeUnK",
#           "indices": [
#             48,
#             71
#           ],
#           "expanded_url": "https://www.Youtube.com/c/Origengg",
#           "display_url": "Youtube.com/c/Origengg"
#         },
#         {
#           "url": "https://t.co/URrSUVt9nZ",
#           "indices": [
#             72,
#             95
#           ],
#           "expanded_url": "http://www.Linkedin.com/company/Origen-gaming",
#           "display_url": "Linkedin.com/company/Origen\u2026"
#         }
#       ]
#     }
#   },
#   "followers_count": 527218,
#   "profile_sidebar_border_color": "000000",
#   "id_str": "2909403579",
#   "profile_background_color": "131516",
#   "listed_count": 473,
#   "status": {
#     "contributors": null,
#     "truncated": false,
#     "text": "RT @Origen_ESP: Vuelve el equipo espa\u00f1ol de @Origengg en #SuperligaOrangeLoL5 contra @VCFeSports.\n\n21:30 CET\n\nPod\u00e9is ir pasando: https://t.\u2026",
#     "is_quote_status": false,
#     "in_reply_to_status_id": null,
#     "id": 839210979468668933,
#     "favorite_count": 0,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "entities": {
#       "symbols": [],
#       "user_mentions": [
#         {
#           "id": 819289227213029384,
#           "indices": [
#             3,
#             14
#           ],
#           "id_str": "819289227213029384",
#           "screen_name": "Origen_ESP",
#           "name": "Origen ESP"
#         },
#         {
#           "id": 2909403579,
#           "indices": [
#             44,
#             53
#           ],
#           "id_str": "2909403579",
#           "screen_name": "Origengg",
#           "name": "Origen"
#         },
#         {
#           "id": 739770958181978112,
#           "indices": [
#             85,
#             96
#           ],
#           "id_str": "739770958181978112",
#           "screen_name": "VCFeSports",
#           "name": "Valencia CF eSports"
#         }
#       ],
#       "hashtags": [
#         {
#           "indices": [
#             57,
#             77
#           ],
#           "text": "SuperligaOrangeLoL5"
#         }
#       ],
#       "urls": []
#     },
#     "in_reply_to_screen_name": null,
#     "in_reply_to_user_id": null,
#     "retweet_count": 21,
#     "id_str": "839210979468668933",
#     "favorited": false,
#     "retweeted_status": {
#       "contributors": null,
#       "truncated": true,
#       "text": "Vuelve el equipo espa\u00f1ol de @Origengg en #SuperligaOrangeLoL5 contra @VCFeSports.\n\n21:30 CET\n\nPod\u00e9is ir pasando:\u2026 https://t.co/QAO8mbRFnY",
#       "is_quote_status": false,
#       "in_reply_to_status_id": null,
#       "id": 839199039585415169,
#       "favorite_count": 80,
#       "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#       "retweeted": false,
#       "coordinates": null,
#       "entities": {
#         "symbols": [],
#         "user_mentions": [
#           {
#             "id": 2909403579,
#             "indices": [
#               28,
#               37
#             ],
#             "id_str": "2909403579",
#             "screen_name": "Origengg",
#             "name": "Origen"
#           },
#           {
#             "id": 739770958181978112,
#             "indices": [
#               69,
#               80
#             ],
#             "id_str": "739770958181978112",
#             "screen_name": "VCFeSports",
#             "name": "Valencia CF eSports"
#           }
#         ],
#         "hashtags": [
#           {
#             "indices": [
#               41,
#               61
#             ],
#             "text": "SuperligaOrangeLoL5"
#           }
#         ],
#         "urls": [
#           {
#             "url": "https://t.co/QAO8mbRFnY",
#             "indices": [
#               114,
#               137
#             ],
#             "expanded_url": "https://twitter.com/i/web/status/839199039585415169",
#             "display_url": "twitter.com/i/web/status/8\u2026"
#           }
#         ]
#       },
#       "in_reply_to_screen_name": null,
#       "in_reply_to_user_id": null,
#       "retweet_count": 21,
#       "id_str": "839199039585415169",
#       "favorited": false,
#       "geo": null,
#       "in_reply_to_user_id_str": null,
#       "possibly_sensitive": false,
#       "lang": "es",
#       "created_at": "Tue Mar 07 19:40:17 +0000 2017",
#       "in_reply_to_status_id_str": null,
#       "place": null
#     },
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "lang": "es",
#     "created_at": "Tue Mar 07 20:27:43 +0000 2017",
#     "in_reply_to_status_id_str": null,
#     "place": null
#   },
#   "is_translation_enabled": false,
#   "utc_offset": 3600,
#   "statuses_count": 3688,
#   "description": "https://t.co/d0e1aUGdht https://t.co/JQQ4SygOb9 https://t.co/eXXJXJeUnK https://t.co/URrSUVt9nZ",
#   "friends_count": 19,
#   "location": "Berlin / Spain",
#   "profile_link_color": "009999",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/652220719770771456/aDxDVzIB_normal.png",
#   "following": true,
#   "geo_enabled": true,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2909403579/1484338058",
#   "blocking": false,
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#   "screen_name": "Origengg",
#   "lang": "es",
#   "profile_background_tile": true,
#   "favourites_count": 2671,
#   "name": "Origen",
#   "notifications": false,
#   "url": "http://t.co/Si7szatA6y",
#   "created_at": "Sun Dec 07 15:58:37 +0000 2014",
#   "contributors_enabled": false,
#   "time_zone": "Bern",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
# }
# {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "live_following": false,
#   "default_profile_image": false,
#   "id": 2886611010,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#   "translator_type": "none",
#   "verified": true,
#   "blocked_by": false,
#   "profile_text_color": "333333",
#   "muting": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/633925327690067968/BjBO8leP_normal.png",
#   "profile_sidebar_fill_color": "EFEFEF",
#   "entities": {
#     "url": {
#       "urls": [
#         {
#           "url": "http://t.co/TWf7N5v1iJ",
#           "indices": [
#             0,
#             22
#           ],
#           "expanded_url": "http://www.playoverwatch.com",
#           "display_url": "playoverwatch.com"
#         }
#       ]
#     },
#     "description": {
#       "urls": []
#     }
#   },
#   "followers_count": 68086,
#   "profile_sidebar_border_color": "EEEEEE",
#   "id_str": "2886611010",
#   "profile_background_color": "131516",
#   "listed_count": 94,
#   "status": {
#     "contributors": null,
#     "truncated": false,
#     "text": "@Epi_Sergio Son exactamente 8, \u00a1no est\u00e1 nada mal! https://t.co/lRPGe3niyr",
#     "is_quote_status": false,
#     "in_reply_to_status_id": 838734913608253440,
#     "id": 839157444764909568,
#     "favorite_count": 1,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "entities": {
#       "symbols": [],
#       "user_mentions": [
#         {
#           "id": 203042057,
#           "indices": [
#             0,
#             11
#           ],
#           "id_str": "203042057",
#           "screen_name": "Epi_Sergio",
#           "name": "Sergio / Epi"
#         }
#       ],
#       "hashtags": [],
#       "urls": [],
#       "media": [
#         {
#           "expanded_url": "https://twitter.com/OverwatchES/status/839157444764909568/photo/1",
#           "display_url": "pic.twitter.com/lRPGe3niyr",
#           "url": "https://t.co/lRPGe3niyr",
#           "media_url_https": "https://pbs.twimg.com/media/C6VJO87WMAAbcyH.jpg",
#           "id_str": "839157426796507136",
#           "sizes": {
#             "large": {
#               "h": 960,
#               "resize": "fit",
#               "w": 1920
#             },
#             "small": {
#               "h": 340,
#               "resize": "fit",
#               "w": 680
#             },
#             "medium": {
#               "h": 600,
#               "resize": "fit",
#               "w": 1200
#             },
#             "thumb": {
#               "h": 150,
#               "resize": "crop",
#               "w": 150
#             }
#           },
#           "indices": [
#             50,
#             73
#           ],
#           "type": "photo",
#           "id": 839157426796507136,
#           "media_url": "http://pbs.twimg.com/media/C6VJO87WMAAbcyH.jpg"
#         }
#       ]
#     },
#     "in_reply_to_screen_name": "Epi_Sergio",
#     "in_reply_to_user_id": 203042057,
#     "retweet_count": 1,
#     "id_str": "839157444764909568",
#     "favorited": false,
#     "geo": null,
#     "in_reply_to_user_id_str": "203042057",
#     "possibly_sensitive": false,
#     "lang": "es",
#     "created_at": "Tue Mar 07 16:55:00 +0000 2017",
#     "in_reply_to_status_id_str": "838734913608253440",
#     "place": null,
#     "extended_entities": {
#       "media": [
#         {
#           "expanded_url": "https://twitter.com/OverwatchES/status/839157444764909568/photo/1",
#           "display_url": "pic.twitter.com/lRPGe3niyr",
#           "url": "https://t.co/lRPGe3niyr",
#           "media_url_https": "https://pbs.twimg.com/media/C6VJO87WMAAbcyH.jpg",
#           "id_str": "839157426796507136",
#           "sizes": {
#             "large": {
#               "h": 960,
#               "resize": "fit",
#               "w": 1920
#             },
#             "small": {
#               "h": 340,
#               "resize": "fit",
#               "w": 680
#             },
#             "medium": {
#               "h": 600,
#               "resize": "fit",
#               "w": 1200
#             },
#             "thumb": {
#               "h": 150,
#               "resize": "crop",
#               "w": 150
#             }
#           },
#           "indices": [
#             50,
#             73
#           ],
#           "type": "photo",
#           "id": 839157426796507136,
#           "media_url": "http://pbs.twimg.com/media/C6VJO87WMAAbcyH.jpg"
#         }
#       ]
#     }
#   },
#   "is_translation_enabled": false,
#   "utc_offset": 3600,
#   "statuses_count": 4133,
#   "description": "El mundo necesita h\u00e9roes. \u00danete hoy a la lucha.",
#   "friends_count": 141,
#   "location": "La Tierra, el futuro",
#   "profile_link_color": "009999",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/633925327690067968/BjBO8leP_normal.png",
#   "following": true,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2886611010/1488481848",
#   "blocking": false,
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#   "screen_name": "OverwatchES",
#   "lang": "en",
#   "profile_background_tile": true,
#   "favourites_count": 2617,
#   "name": "Overwatch",
#   "notifications": false,
#   "url": "http://t.co/TWf7N5v1iJ",
#   "created_at": "Sat Nov 01 19:26:39 +0000 2014",
#   "contributors_enabled": false,
#   "time_zone": "Paris",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
# }
# {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "live_following": false,
#   "default_profile_image": false,
#   "id": 3388614177,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "translator_type": "none",
#   "verified": false,
#   "blocked_by": false,
#   "profile_text_color": "333333",
#   "muting": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/633621403410018304/JCZemqSh_normal.png",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "url": {
#       "urls": [
#         {
#           "url": "https://t.co/mPvMAozChZ",
#           "indices": [
#             0,
#             23
#           ],
#           "expanded_url": "https://www.youtube.com/c/esportmaniacosshow",
#           "display_url": "youtube.com/c/esportmaniac\u2026"
#         }
#       ]
#     },
#     "description": {
#       "urls": []
#     }
#   },
#   "followers_count": 9736,
#   "profile_sidebar_border_color": "C0DEED",
#   "id_str": "3388614177",
#   "profile_background_color": "C0DEED",
#   "listed_count": 89,
#   "status": {
#     "contributors": null,
#     "truncated": false,
#     "text": "El programa de hoy est\u00e1 disponible en Youtube. \n\nhttps://t.co/6sgkJNSfuS",
#     "is_quote_status": false,
#     "in_reply_to_status_id": null,
#     "id": 839226659869974530,
#     "favorite_count": 0,
#     "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "entities": {
#       "symbols": [],
#       "user_mentions": [],
#       "hashtags": [],
#       "urls": [
#         {
#           "url": "https://t.co/6sgkJNSfuS",
#           "indices": [
#             49,
#             72
#           ],
#           "expanded_url": "https://www.youtube.com/watch?v=Y1BYH8SOaZ8&lc",
#           "display_url": "youtube.com/watch?v=Y1BYH8\u2026"
#         }
#       ]
#     },
#     "in_reply_to_screen_name": null,
#     "in_reply_to_user_id": null,
#     "retweet_count": 1,
#     "id_str": "839226659869974530",
#     "favorited": false,
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "possibly_sensitive": false,
#     "lang": "es",
#     "created_at": "Tue Mar 07 21:30:02 +0000 2017",
#     "in_reply_to_status_id_str": null,
#     "place": null
#   },
#   "is_translation_enabled": false,
#   "utc_offset": 3600,
#   "statuses_count": 25110,
#   "description": "Hacemos Gaming Talk Shows para gente con sentido cr\u00edtico, del humor, y un poco de amor. Bueno, amor no.\n\nContacto: esportmaniacos@gmail.com",
#   "friends_count": 61,
#   "location": "twitch.tv/esportmaniacos",
#   "profile_link_color": "1DA1F2",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/633621403410018304/JCZemqSh_normal.png",
#   "following": true,
#   "geo_enabled": true,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/3388614177/1439902038",
#   "blocking": false,
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "screen_name": "eSportManiacos",
#   "lang": "es",
#   "profile_background_tile": false,
#   "favourites_count": 7532,
#   "name": "esportman\u00edacos",
#   "notifications": false,
#   "url": "https://t.co/mPvMAozChZ",
#   "created_at": "Thu Jul 23 06:21:34 +0000 2015",
#   "contributors_enabled": false,
#   "time_zone": "Madrid",
#   "protected": false,
#   "default_profile": true,
#   "is_translator": false
# }
# {
#   "follow_request_sent": false,
#   "has_extended_profile": true,
#   "profile_use_background_image": false,
#   "live_following": false,
#   "default_profile_image": false,
#   "id": 3004319596,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/560891660360368128/C_J-nXQG.jpeg",
#   "translator_type": "none",
#   "verified": false,
#   "blocked_by": false,
#   "profile_text_color": "333333",
#   "muting": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/774475510344671233/5Tmmexxy_normal.jpg",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "url": {
#       "urls": [
#         {
#           "url": "https://t.co/BNCYaOxfFS",
#           "indices": [
#             0,
#             23
#           ],
#           "expanded_url": "http://instagram.com/cxlibri",
#           "display_url": "instagram.com/cxlibri"
#         }
#       ]
#     },
#     "description": {
#       "urls": []
#     }
#   },
#   "followers_count": 14783,
#   "profile_sidebar_border_color": "C0DEED",
#   "id_str": "3004319596",
#   "profile_background_color": "121011",
#   "listed_count": 20,
#   "status": {
#     "contributors": null,
#     "truncated": false,
#     "text": "@TL_Goldenglue let me know if I can help with anything \ud83d\ude4c",
#     "is_quote_status": false,
#     "in_reply_to_status_id": 838846788442304512,
#     "id": 839161823500738561,
#     "favorite_count": 2,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "entities": {
#       "symbols": [],
#       "user_mentions": [
#         {
#           "id": 358962590,
#           "indices": [
#             0,
#             14
#           ],
#           "id_str": "358962590",
#           "screen_name": "TL_Goldenglue",
#           "name": "Greyson Gilmer"
#         }
#       ],
#       "hashtags": [],
#       "urls": []
#     },
#     "in_reply_to_screen_name": "TL_Goldenglue",
#     "in_reply_to_user_id": 358962590,
#     "retweet_count": 0,
#     "id_str": "839161823500738561",
#     "favorited": false,
#     "geo": null,
#     "in_reply_to_user_id_str": "358962590",
#     "lang": "en",
#     "created_at": "Tue Mar 07 17:12:24 +0000 2017",
#     "in_reply_to_status_id_str": "838846788442304512",
#     "place": null
#   },
#   "is_translation_enabled": true,
#   "utc_offset": 3600,
#   "statuses_count": 2462,
#   "description": "Currently studying in South Korea. Send me puppy snaps @ cxlibri \u2661",
#   "friends_count": 319,
#   "location": "\ub300\ud55c\ubbfc\uad6d \uc11c\uc6b8",
#   "profile_link_color": "F58EA8",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/774475510344671233/5Tmmexxy_normal.jpg",
#   "following": true,
#   "geo_enabled": true,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/3004319596/1455483840",
#   "blocking": false,
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/560891660360368128/C_J-nXQG.jpeg",
#   "screen_name": "cxlibri",
#   "lang": "en",
#   "profile_background_tile": false,
#   "favourites_count": 1895,
#   "name": "Yuli",
#   "notifications": false,
#   "url": "https://t.co/BNCYaOxfFS",
#   "created_at": "Thu Jan 29 19:35:58 +0000 2015",
#   "contributors_enabled": false,
#   "time_zone": "Belgrade",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
# }
# {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "live_following": false,
#   "default_profile_image": false,
#   "id": 19622847,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/458597357769068544/oVfeZ4jb.jpeg",
#   "translator_type": "none",
#   "verified": true,
#   "blocked_by": false,
#   "profile_text_color": "333333",
#   "muting": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/516372983808393216/k7PvYZYh_normal.png",
#   "profile_sidebar_fill_color": "999999",
#   "entities": {
#     "url": {
#       "urls": [
#         {
#           "url": "http://t.co/cYtWJORUJm",
#           "indices": [
#             0,
#             22
#           ],
#           "expanded_url": "http://www.akamai.com/",
#           "display_url": "akamai.com"
#         }
#       ]
#     },
#     "description": {
#       "urls": []
#     }
#   },
#   "followers_count": 113867,
#   "profile_sidebar_border_color": "FFFFFF",
#   "id_str": "19622847",
#   "profile_background_color": "C0DEED",
#   "listed_count": 1401,
#   "status": {
#     "contributors": null,
#     "truncated": true,
#     "text": "Securing a 21st century government is no easy task. Join us on 3/28 to discuss how you can combat cyber threats:\u2026 https://t.co/jSaRuJVaZy",
#     "is_quote_status": false,
#     "in_reply_to_status_id": null,
#     "id": 839204041020354560,
#     "favorite_count": 3,
#     "source": "<a href=\"http://sproutsocial.com\" rel=\"nofollow\">Sprout Social</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "entities": {
#       "symbols": [],
#       "user_mentions": [],
#       "hashtags": [],
#       "urls": [
#         {
#           "url": "https://t.co/jSaRuJVaZy",
#           "indices": [
#             114,
#             137
#           ],
#           "expanded_url": "https://twitter.com/i/web/status/839204041020354560",
#           "display_url": "twitter.com/i/web/status/8\u2026"
#         }
#       ]
#     },
#     "in_reply_to_screen_name": null,
#     "in_reply_to_user_id": null,
#     "retweet_count": 1,
#     "id_str": "839204041020354560",
#     "favorited": false,
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "possibly_sensitive": false,
#     "lang": "en",
#     "created_at": "Tue Mar 07 20:00:09 +0000 2017",
#     "in_reply_to_status_id_str": null,
#     "place": null
#   },
#   "is_translation_enabled": false,
#   "utc_offset": -18000,
#   "statuses_count": 19389,
#   "description": "The global leader in #cdn + #cloud services, #Akamai makes the #Internet fast, reliable and #secure. Latest trends on #webperf, #websecurity, #video #streaming.",
#   "friends_count": 3039,
#   "location": "Cambridge, MA",
#   "profile_link_color": "0099CC",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/516372983808393216/k7PvYZYh_normal.png",
#   "following": true,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/19622847/1477428304",
#   "blocking": false,
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/458597357769068544/oVfeZ4jb.jpeg",
#   "screen_name": "Akamai",
#   "lang": "en",
#   "profile_background_tile": true,
#   "favourites_count": 2551,
#   "name": "Akamai Technologies",
#   "notifications": false,
#   "url": "http://t.co/cYtWJORUJm",
#   "created_at": "Tue Jan 27 22:58:24 +0000 2009",
#   "contributors_enabled": false,
#   "time_zone": "Eastern Time (US & Canada)",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
# }
# {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "live_following": false,
#   "default_profile_image": false,
#   "id": 44992826,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/471540715617398784/VUI8nKRl.png",
#   "translator_type": "none",
#   "verified": true,
#   "blocked_by": false,
#   "profile_text_color": "333333",
#   "muting": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/804311000786812928/k69lhtG8_normal.jpg",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "url": {
#       "urls": [
#         {
#           "url": "https://t.co/BYySrlvWbC",
#           "indices": [
#             0,
#             23
#           ],
#           "expanded_url": "http://bit.ly/2eLCKnW",
#           "display_url": "bit.ly/2eLCKnW"
#         }
#       ]
#     },
#     "description": {
#       "urls": [
#         {
#           "url": "https://t.co/BYySrlvWbC",
#           "indices": [
#             120,
#             143
#           ],
#           "expanded_url": "http://bit.ly/2eLCKnW",
#           "display_url": "bit.ly/2eLCKnW"
#         }
#       ]
#     }
#   },
#   "followers_count": 346944,
#   "profile_sidebar_border_color": "FFFFFF",
#   "id_str": "44992826",
#   "profile_background_color": "0080A3",
#   "listed_count": 3006,
#   "status": {
#     "contributors": null,
#     "truncated": false,
#     "text": "@srcoke95  Tienes que llamar al n\u00famero que te ha facilitado mi compa\u00f1era. Un saludo. Esmeralda.",
#     "is_quote_status": false,
#     "in_reply_to_status_id": 839199947639697408,
#     "id": 839217183955763200,
#     "favorite_count": 0,
#     "source": "<a href=\"http://engagor.com\" rel=\"nofollow\">Engagor</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "entities": {
#       "symbols": [],
#       "user_mentions": [
#         {
#           "id": 453831317,
#           "indices": [
#             0,
#             9
#           ],
#           "id_str": "453831317",
#           "screen_name": "SrCoke95",
#           "name": "Sr. Coke"
#         }
#       ],
#       "hashtags": [],
#       "urls": []
#     },
#     "in_reply_to_screen_name": "SrCoke95",
#     "in_reply_to_user_id": 453831317,
#     "retweet_count": 0,
#     "id_str": "839217183955763200",
#     "favorited": false,
#     "geo": null,
#     "in_reply_to_user_id_str": "453831317",
#     "lang": "es",
#     "created_at": "Tue Mar 07 20:52:23 +0000 2017",
#     "in_reply_to_status_id_str": "839199947639697408",
#     "place": null
#   },
#   "is_translation_enabled": false,
#   "utc_offset": 3600,
#   "statuses_count": 247754,
#   "description": "S\u00edguenos para conocer todas nuestras ofertas y novedades. Estamos aqu\u00ed para resolver tus dudas y ayudarte. #EligeTodo I https://t.co/BYySrlvWbC",
#   "friends_count": 348847,
#   "location": "Espa\u00f1a",
#   "profile_link_color": "0084B4",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/804311000786812928/k69lhtG8_normal.jpg",
#   "following": true,
#   "geo_enabled": true,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/44992826/1488792869",
#   "blocking": false,
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/471540715617398784/VUI8nKRl.png",
#   "screen_name": "movistar_es",
#   "lang": "es",
#   "profile_background_tile": true,
#   "favourites_count": 3181,
#   "name": "Movistar Espa\u00f1a",
#   "notifications": false,
#   "url": "https://t.co/BYySrlvWbC",
#   "created_at": "Fri Jun 05 20:52:25 +0000 2009",
#   "contributors_enabled": false,
#   "time_zone": "Madrid",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
# }

# %%
# It is easy to get my last tweet in JSON
for tweet in tweepy.Cursor(api.user_timeline).items(1):
    print(json.dumps(tweet._json, indent=2))
# Out:
# {
#   "contributors": null,
#   "truncated": false,
#   "text": "@beselcouth s\u00ed",
#   "is_quote_status": false,
#   "in_reply_to_status_id": 839055582757851138,
#   "id": 839062003389968384,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#     "symbols": [],
#     "user_mentions": [
#       {
#         "id": 4001285297,
#         "indices": [
#           0,
#           11
#         ],
#         "id_str": "4001285297",
#         "screen_name": "beselcouth",
#         "name": "Art S"
#       }
#     ],
#     "hashtags": [],
#     "urls": []
#   },
#   "in_reply_to_screen_name": "beselcouth",
#   "in_reply_to_user_id": 4001285297,
#   "retweet_count": 0,
#   "id_str": "839062003389968384",
#   "favorited": false,
#   "user": {
#     "follow_request_sent": false,
#     "has_extended_profile": true,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 19491045,
#     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/692806416806055936/nPte7Tv2.jpg",
#     "verified": false,
#     "translator_type": "regular",
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/668521871986581504/cKJkTc7v_normal.jpg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#       "url": {
#         "urls": [
#           {
#             "url": "https://t.co/0Af91020jk",
#             "indices": [
#               0,
#               23
#             ],
#             "expanded_url": "http://eloygil.com",
#             "display_url": "eloygil.com"
#           }
#         ]
#       },
#       "description": {
#         "urls": []
#       }
#     },
#     "followers_count": 557,
#     "profile_sidebar_border_color": "000000",
#     "id_str": "19491045",
#     "profile_background_color": "89C9FA",
#     "listed_count": 21,
#     "is_translation_enabled": false,
#     "utc_offset": 3600,
#     "statuses_count": 39123,
#     "description": "199x. Designed in Navarra, assembled in Barcelona. Professional photographer, computer sciences by punishment. Proud shareholder of Twitter & Facebook.",
#     "friends_count": 58,
#     "location": "\u00abTo be or not to be...\u00bb in BCN",
#     "profile_link_color": "3B94D9",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/668521871986581504/cKJkTc7v_normal.jpg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/19491045/1481561652",
#     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/692806416806055936/nPte7Tv2.jpg",
#     "screen_name": "eloyweb",
#     "lang": "es",
#     "profile_background_tile": true,
#     "favourites_count": 698,
#     "name": "Eloy 'eloyweb' Gil",
#     "notifications": false,
#     "url": "https://t.co/0Af91020jk",
#     "created_at": "Sun Jan 25 15:12:47 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Madrid",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": "4001285297",
#   "lang": "und",
#   "created_at": "Tue Mar 07 10:35:45 +0000 2017",
#   "in_reply_to_status_id_str": "839055582757851138",
#   "place": null
# }
